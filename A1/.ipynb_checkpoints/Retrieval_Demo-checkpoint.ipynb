# %%
# %load_ext autoreload
# %autoreload 1

# %%
from vsm import *
from brm import *

# %%
VSM().query("(operating OR systems) AND (NOT data)", top_n=10)
# Out:
#                                                 title  \
# id
# 12               CSI 3131 Operating Systems (3 units)
# 69   CSI 5152 Evolving Information Networks (3 units)
# 32        CSI 4141 Real Time Systems Design (3 units)
# 88  CSI 5308 Principles of Distributed Computing (...
# 33    CSI 4142 Introduction to Data Science (3 units)
# 83    CSI 5175 Mobile Commerce Technologies (3 units)
# 92  CSI 5380 Systems and Architectures for Electro...
# 43  CSI 5113 Foundations Programming Languages (3 ...
# 82  CSI 5174 Validation Methods for Distributed Sy...
# 30  CSI 4139 Design of Secure Computer Systems (3 ...
#
#                                                  body  confidence
# id
# 12  Principles of operating systems. Operating sys...    0.999623
# 69  Data management problems and information techn...    0.987856
# 32  Definition of real-time systems;  examples.  C...    0.986274
# 88  Design issues of advanced multiprocessor distr...    0.979147
# ...

# %%
BRM().query("(computer OR systems) AND (data)")
# Out:
#                                                 title  \
# id
# 0   CSI 1306 Computing Concepts for Business (3 un...
# 2        CSI 1390 Introduction to Computers (3 units)
# 21  CSI 4109 Introduction to Distributed Computing...
# 27               CSI 4130 Computer Graphics (3 units)
# 43  CSI 5113 Foundations Programming Languages (3 ...
# 52              CSI 5128 Swarm Intelligence (3 units)
# 67  CSI 5149 Graphical Models and Applications (3 ...
# 69   CSI 5152 Evolving Information Networks (3 units)
# 70  CSI 5153 Data Management for Business Intellig...
# 87     CSI 5200 Projects on Selected Topics (3 units)
#
#                                                  body
# id
# 0   Introduction to computer-based problem solving...
# 2   Computing and computers. Problem solving and a...
# 21  Computational models. Communication complexity...
# 27  Interactive computer graphics. Display data st...
# 43  The dimensional and multidimensional data mode...
# ...
