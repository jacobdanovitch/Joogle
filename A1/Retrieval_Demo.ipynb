# %%
# %load_ext autoreload
# %autoreload 1

# %%
from vsm import *
from brm import *

# %%
VSM().query("operating systems", top_n=10)
# Out:
#                                                 title  \
# id
# 12               CSI 3131 Operating Systems (3 units)
# 32        CSI 4141 Real Time Systems Design (3 units)
# 88  CSI 5308 Principles of Distributed Computing (...
# 83    CSI 5175 Mobile Commerce Technologies (3 units)
# 30  CSI 4139 Design of Secure Computer Systems (3 ...
# 82  CSI 5174 Validation Methods for Distributed Sy...
# 55  CSI 5131 Parallel Algorithms and Applications ...
# 89  CSI 5311 Distributed Databases and Transaction...
# 81                   CSI 5173 Data Networks (3 units)
# 52              CSI 5128 Swarm Intelligence (3 units)
#
#                                                  body  confidence
# id
# 12  Principles of operating systems. Operating sys...    0.999623
# 32  Definition of real-time systems;  examples.  C...    0.986274
# 88  Design issues of advanced multiprocessor distr...    0.979147
# 83  Selected topics in Artificial Intelligence (A....    0.975010
# ...

# %%
BRM().query("(computer OR systems) AND (data)")
# Out:
#                                                 title  \
# id
# 0   CSI 1306 Computing Concepts for Business (3 un...
# 2        CSI 1390 Introduction to Computers (3 units)
# 21  CSI 4109 Introduction to Distributed Computing...
# 27               CSI 4130 Computer Graphics (3 units)
# 43  CSI 5113 Foundations Programming Languages (3 ...
# 52              CSI 5128 Swarm Intelligence (3 units)
# 67  CSI 5149 Graphical Models and Applications (3 ...
# 69   CSI 5152 Evolving Information Networks (3 units)
# 70  CSI 5153 Data Management for Business Intellig...
# 87     CSI 5200 Projects on Selected Topics (3 units)
#
#                                                  body
# id
# 0   Introduction to computer-based problem solving...
# 2   Computing and computers. Problem solving and a...
# 21  Computational models. Communication complexity...
# 27  Interactive computer graphics. Display data st...
# 43  The dimensional and multidimensional data mode...
# ...

# %%
m = VSM()
m.term_dict
# Out:
# {'introduction': {0: 1, 1: 1, 2: 1, 6: 1, 10: 1, 18: 1, 50: 1},
#  'computerbased': {0: 1},
#  'problem': {0: 3,
#   1: 1,
#   2: 1,
#   3: 1,
#   4: 1,
#   5: 1,
#   8: 1,
#   9: 2,
#   14: 1,
#   17: 1,
#   34: 2,
#   46: 1,
#   48: 1,
#   50: 1,
#   51: 1,
#   54: 1,
#   69: 1,
#   74: 2,
#   75: 2,
#   84: 1,
#   86: 2,
#   100: 1},
#  'solving': {0: 3, 1: 1, 2: 1, 5: 1, 48: 1, 50: 1, 54: 1, 75: 2, 86: 1},
#  'perspective': {0: 1, 24: 1, 42: 1, 48: 1, 54: 1},
#  'business': {0: 3, 69: 2, 82: 1, 93: 1},
#  'world': {0: 1, 19: 1, 67: 2},
#  'design': {0: 2,
#   1: 1,
#   3: 1,
#   5: 1,
#   6: 2,
#   9: 1,
#   10: 2,
#   11: 2,
#   12: 1,
#   21: 1,
#   23: 1,
#   30: 1,
#   31: 1,
#   32: 2,
#   40: 4,
#   45: 1,
#   46: 1,
#   47: 1,
#   48: 1,
#   50: 2,
#   55: 1,
#   57: 3,
#   68: 1,
#   73: 1,
#   74: 1,
#   75: 1,
#   77: 2,
#   79: 1,
#   80: 1,
#   86: 1,
#   87: 1,
#   88: 1,
#   89: 1,
#   90: 2,
#   94: 1},
#  'algorithm': {0: 1,
#   1: 2,
#   2: 1,
#   3: 1,
# ...

# %%
# Out:
# ([(0,
#    ['introduction',
#     'computerbased',
#     'problem',
#     'solving',
#     'perspective',
#     'business',
#     'world',
#     'design',
#     'algorithm',
#     'solving',
#     'business',
#     'problem',
#     'basic',
#     'computer',
#     'programming',
#     'modern',
#     'programming',
#     'language',
#     'solving',
#     'business',
#     'problem',
#     'using',
#     'application',
#     'package',
#     'including',
#     'spreadsheet',
#     'database',
#     'basic',
#     'web',
#     'design',
#     'collaborative',
#     'tool',
#     'using',
#     'open',
#     'source',
#     'software']),
#   (1,
#    ['introduction',
#     'computer',
#     'based',
#     'problem',
#     'solving',
#     'scientific',
#     'application',
#     'design',
#     'algorithm',
#     'algorithm',
#     'description',
#     'generation',
#     'language',
#     'software',
#     'package',
#     'structured',
#     'program',
#     'development',
# ...
